# %%
import pandas as pd
import pandasql as pds
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pyodbc as pdb

# %%
#pip install pyodbc
conn=pdb.connect('DRIVER=SQL SERVER;' 'SERVER=localhost;' 'DATABASE=NorthWind;' 'Trusted_Connection=yes;')

# %%
df=pd.read_sql_query("""SELECT * FROM ORDERS""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\33793183.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("""SELECT * FROM ORDERS""",conn)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      OrderID CustomerID  EmployeeID  OrderDate RequiredDate ShippedDate  \
# 0      10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
# 1      10249      TOMSP           6 1996-07-05   1996-08-16  1996-07-10
# 2      10250      HANAR           4 1996-07-08   1996-08-05  1996-07-12
# 3      10251      VICTE           3 1996-07-08   1996-08-05  1996-07-15
# 4      10252      SUPRD           4 1996-07-09   1996-08-06  1996-07-11
# ..       ...        ...         ...        ...          ...         ...
# 825    11073      PERIC           2 1998-05-05   1998-06-02         NaT
# 826    11074      SIMOB           7 1998-05-06   1998-06-03         NaT
# 827    11075      RICSU           8 1998-05-06   1998-06-03         NaT
# 828    11076      BONAP           4 1998-05-06   1998-06-03         NaT
# 829    11077      RATTC           1 1998-05-06   1998-06-03         NaT
#
#      ShipVia  Freight                    ShipName               ShipAddress  \
# ...

# %%
pd.read_sql_query("""SELECT * FROM ORDERS
    WHERE CUSTOMERID='VINET' """,conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\883665873.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""SELECT * FROM ORDERS
#    OrderID CustomerID  EmployeeID  OrderDate RequiredDate ShippedDate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
# 1    10274      VINET           6 1996-08-06   1996-09-03  1996-08-16
# 2    10295      VINET           2 1996-09-02   1996-09-30  1996-09-10
# 3    10737      VINET           2 1997-11-11   1997-12-09  1997-11-18
# 4    10739      VINET           3 1997-11-12   1997-12-10  1997-11-17
#
#    ShipVia  Freight                   ShipName         ShipAddress ShipCity  \
# 0        3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1        1     6.01  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# ...

# %%
pd.read_sql_query("""SELECT * FROM ORDERS
    WHERE CUSTOMERID LIKE 'V%' """,conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\3722224138.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""SELECT * FROM ORDERS
#     OrderID CustomerID  EmployeeID  OrderDate RequiredDate ShippedDate  \
# 0     10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
# 1     10251      VICTE           3 1996-07-08   1996-08-05  1996-07-15
# 2     10274      VINET           6 1996-08-06   1996-09-03  1996-08-16
# 3     10295      VINET           2 1996-09-02   1996-09-30  1996-09-10
# 4     10334      VICTE           8 1996-10-21   1996-11-18  1996-10-28
# 5     10367      VAFFE           7 1996-11-28   1996-12-26  1996-12-02
# 6     10399      VAFFE           8 1996-12-31   1997-01-14  1997-01-08
# 7     10450      VICTE           8 1997-02-19   1997-03-19  1997-03-11
# ...

# %%
pd.read_sql_query("""SELECT SupplierID,AVG(UnitPrice) AS 'AVG'
FROM Products
GROUP BY SupplierID""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\3024830830.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""SELECT SupplierID,AVG(UnitPrice) AS 'AVG'
#     SupplierID       AVG
# 0            1   15.6666
# 1            2   20.3500
# 2            3   31.6666
# 3            4   46.0000
# 4            5   29.5000
# 5            6   14.9166
# 6            7   35.5700
# 7            8   28.1750
# 8            9   15.0000
# 9           10    4.5000
# 10          11   29.7100
# 11          12   44.6780
# 12          13   25.8900
# 13          14   26.4333
# 14          15   20.0000
# 15          16   15.3333
# 16          17   20.0000
# 17          18  140.7500
# 18          19   14.0250
# 19          20   26.4833
# 20          21   10.7500
# 21          22   11.1250
# 22          23   18.0833
# ...

# %% [raw]
# 1.create plot that will show the top 10 customers that spends most
# 2.create a plot that show how many suppliers came from each country
# 3.create a plot that show how many orders came from each country
# 4.create a plot that will show how many products in each category each supplier supply
# pd.read_sql_query("""SELECT SupplierID,AVG(UnitPrice) AS 'AVG'
# FROM Products
# GROUP BY SupplierID""",conn)

# %%
t10=pd.read_sql_query("""SELECT TOP 10 CustomerID,SUM(UnitPrice*Quantity) su
FROM Orders o JOIN [Order Details] od
ON o.OrderID=od.OrderID
GROUP BY CustomerID
ORDER BY SUM(UnitPrice*Quantity) DESC""",conn)
sns.barplot(data=t10,x='CustomerID',y='su')
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\4103633491.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   t10=pd.read_sql_query("""SELECT TOP 10 CustomerID,SUM(UnitPrice*Quantity) su
# <Axes: xlabel='CustomerID', ylabel='su'>

# %%
t10
# Out:
#   CustomerID         su
# 0      QUICK  117483.39
# 1      SAVEA  115673.39
# 2      ERNSH  113236.68
# 3      HUNGO   57317.39
# 4      RATTC   52245.90
# 5      HANAR   34101.15
# 6      FOLKO   32555.55
# 7      MEREP   32203.90
# 8      KOENE   31745.75
# 9      QUEEN   30226.10

# %%
sup=pd.read_sql_query("""SELECT Country,COUNT(*) cnt
FROM Suppliers
GROUP BY Country""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\3979040943.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sup=pd.read_sql_query("""SELECT Country,COUNT(*) cnt

# %%
sup
# Out:
#         Country  cnt
# 0     Australia    2
# 1        Brazil    1
# 2        Canada    2
# 3       Denmark    1
# 4       Finland    1
# 5        France    3
# 6       Germany    3
# 7         Italy    2
# 8         Japan    2
# 9   Netherlands    1
# 10       Norway    1
# 11    Singapore    1
# 12        Spain    1
# 13       Sweden    2
# 14           UK    2
# 15          USA    4

# %%
sup1=pd.read_sql_query("""SELECT *
FROM Suppliers""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\483568173.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sup1=pd.read_sql_query("""SELECT *

# %%
sup1['Country'].value_counts()
# Out:
# Country
# USA            4
# Germany        3
# France         3
# Japan          2
# Sweden         2
# Australia      2
# Italy          2
# UK             2
# Canada         2
# Spain          1
# Brazil         1
# Norway         1
# Singapore      1
# Denmark        1
# Netherlands    1
# Finland        1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
ax=sns.barplot(data=sup,x='Country',y='cnt')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\1308426739.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
# [Text(0, 0, 'Australia'),
#  Text(1, 0, 'Brazil'),
#  Text(2, 0, 'Canada'),
#  Text(3, 0, 'Denmark'),
#  Text(4, 0, 'Finland'),
#  Text(5, 0, 'France'),
#  Text(6, 0, 'Germany'),
#  Text(7, 0, 'Italy'),
#  Text(8, 0, 'Japan'),
#  Text(9, 0, 'Netherlands'),
#  Text(10, 0, 'Norway'),
#  Text(11, 0, 'Singapore'),
#  Text(12, 0, 'Spain'),
#  Text(13, 0, 'Sweden'),
#  Text(14, 0, 'UK'),
#  Text(15, 0, 'USA')]

# %%
plt.figure(figsize=(20,10))
ax=sns.barplot(data=sup,x='Country',y='cnt')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\3481359936.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# [Text(0, 0, 'Australia'),
#  Text(1, 0, 'Brazil'),
#  Text(2, 0, 'Canada'),
#  Text(3, 0, 'Denmark'),
#  Text(4, 0, 'Finland'),
#  Text(5, 0, 'France'),
#  Text(6, 0, 'Germany'),
#  Text(7, 0, 'Italy'),
#  Text(8, 0, 'Japan'),
#  Text(9, 0, 'Netherlands'),
#  Text(10, 0, 'Norway'),
#  Text(11, 0, 'Singapore'),
#  Text(12, 0, 'Spain'),
#  Text(13, 0, 'Sweden'),
#  Text(14, 0, 'UK'),
#  Text(15, 0, 'USA')]

# %%
plt.figure(figsize=(10,10))
ax=sns.barplot(data=sup,y='Country',x='cnt')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\3166856856.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# [Text(0.0, 0, '0.0'),
#  Text(0.5, 0, '0.5'),
#  Text(1.0, 0, '1.0'),
#  Text(1.5, 0, '1.5'),
#  Text(2.0, 0, '2.0'),
#  Text(2.5, 0, '2.5'),
#  Text(3.0, 0, '3.0'),
#  Text(3.5, 0, '3.5'),
#  Text(4.0, 0, '4.0'),
#  Text(4.5, 0, '4.5')]

# %%
ord=pd.read_sql_query("""SELECT shipCountry,COUNT(*) cnt
FROM orders
GROUP BY shipCountry""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\947417052.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ord=pd.read_sql_query("""SELECT shipCountry,COUNT(*) cnt

# %%
ord
# Out:
#     shipCountry  cnt
# 0       Finland   22
# 1           USA  122
# 2         Italy   28
# 3        Brazil   83
# 4       Germany  122
# 5   Switzerland   18
# 6        Mexico   28
# 7        Sweden   37
# 8     Argentina   16
# 9       Austria   40
# 10           UK   56
# 11       Poland    7
# 12       Canada   30
# 13      Ireland   19
# 14       Norway    6
# 15       France   77
# 16      Belgium   19
# 17        Spain   23
# 18    Venezuela   46
# 19      Denmark   18
# 20     Portugal   13

# %%
ord1=pd.read_sql_query("""SELECT *
FROM orders""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\1100451119.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ord1=pd.read_sql_query("""SELECT *

# %%
ax=sns.countplot(data=ord1,x='ShipCountry')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
for x in ax.containers:
    ax.bar_label(x)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\350192261.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')

# %%
plt.figure(figsize=(10,10))
ax=sns.countplot(data=ord1,x='ShipCountry')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
for i in range(len(ax.containers)):
    ax.bar_label(ax.containers[i])
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\1196380615.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')

# %%
q4=pd.read_sql_query("""select productid,supplierid,categoryid
from products""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\2000482116.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   q4=pd.read_sql_query("""select productid,supplierid,categoryid

# %%
q4
# Out:
#     productid  supplierid  categoryid
# 0           1           1           1
# 1           2           1           1
# 2           3           1           2
# 3           4           2           2
# 4           5           2           2
# ..        ...         ...         ...
# 72         73          17           8
# 73         74           4           7
# 74         75          12           1
# 75         76          23           1
# 76         77          12           2
#
# [77 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=q4,x='categoryid',hue='supplierid')
# Out:
# <Axes: xlabel='categoryid', ylabel='count'>

# %%
q41=pd.read_sql_query("""select supplierid,categoryid,count(*) cnt
from products
group by supplierid,categoryid""",conn)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_19020\1689795811.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   q41=pd.read_sql_query("""select supplierid,categoryid,count(*) cnt

# %%
q41
# Out:
#     supplierid  categoryid  cnt
# 0            1           1    2
# 1            7           1    1
# 2           10           1    1
# 3           12           1    1
# 4           16           1    3
# 5           18           1    2
# 6           20           1    1
# 7           23           1    1
# 8            1           2    1
# 9            2           2    4
# 10           3           2    2
# 11           6           2    1
# 12           7           2    1
# 13          12           2    1
# 14          20           2    1
# 15          29           2    1
# 16           7           3    1
# 17           8           3    4
# 18          11           3    3
# 19          22           3    2
# 20          23           3    2
# 21          29           3    1
# 22           5           4    2
# 23          14           4    3
# 24          15           4    3
# 25          28           4    2
# 26           9           5    2
# 27          12           5    1
# ...

# %%
sns.barplot(data=q41,x='supplierid',y='cnt',hue='categoryid')
# Out:
# <Axes: xlabel='supplierid', ylabel='cnt'>
